# %%
import numpy as np
import astropy.io.fits as fits 
import matplotlib.pyplot as plt
from scipy import ndimage
import random
from scipy.optimize import leastsq
import astropy.units as u
from astropy.cosmology import FlatLambdaCDM
from muse import *

# %%
hdu = fits.open('HE0232-0900.wo_absorption.fits')
#hdu.info()
qso_data = hdu[0].data
qso_error = hdu[1].data
qso_header = hdu[0].header
wavstart = qso_header['CRVAL3']
wavint = qso_header['CD3_3']
#wave = wavestart+np.arange(qso_data.shape[0])*wavint. This is the same as the one below. 
[central_x,central_y]= [67,51]#

# %%
mini_cube = qso_data[:,central_y - 7:central_y + 8,central_x - 7:central_x + 8]
mini_cube_error = qso_error[:,central_y - 7:central_y + 8,central_x - 7:central_x + 8]
qso_header['CRPIX1'] = qso_header['CRPIX1'] - (central_x - 7)
qso_header['CRPIX2'] = qso_header['CRPIX2'] - (central_y - 7)
new_hdu = fits.HDUList([fits.PrimaryHDU(mini_cube),fits.ImageHDU(mini_cube_error)])
new_hdu[0].header = qso_header
wave = np.arange(wavstart,(wavstart+(wavint*mini_cube.shape[0])),wavint)#start,stop,step

# %%
z =0.043143 
k = 1+z
mini_data = mini_cube
mini_error = mini_cube_error

# %%
image1=mini_cube[0,:,:]
plt.imshow(image1,cmap='inferno')
plt.show()

# %%
plt.imshow(image1,cmap='inferno',origin='lower',interpolation='nearest')
plt.show()

# %%
w80 = np.zeros((mini_data.shape[1],mini_data.shape[2]),dtype=np.float32)
vel_diff = np.zeros((mini_data.shape[1],mini_data.shape[2]),dtype=np.float32)
flux_narrow = np.zeros((mini_data.shape[1],mini_data.shape[2]),dtype=np.float32)
flux_broad = np.zeros((mini_data.shape[1],mini_data.shape[2]),dtype=np.float32)
flux_total = np.zeros((mini_data.shape[1],mini_data.shape[2]),dtype=np.float32)
v5 = np.zeros((mini_data.shape[1],mini_data.shape[2]),dtype=np.float32)

# %%
np.seterr(divide='ignore', invalid='ignore')
for i in range(mini_data.shape[1]):
    for j in range(mini_data.shape[2]):
        spectrum = mini_data[:,i,j]
        wave = np.arange(wavstart,(wavstart+(wavint*mini_data.shape[0])),wavint)
        select = (wave > 4750*k) & (wave < 5090*k) 
        select1 = (spectrum> 0.08)
        n = len(wave[select])
        mean = sum(wave[select]*spectrum[select])/n
        sigma = sum(spectrum[select]*(wave[select]-mean)**2)/n  
        
        x = wave[select]
        y = spectrum[select]
        y_err = mini_error[:,i,j][select]
        
        if np.max(spectrum[select1]) > 0.5:
                popt2,pcov2 = leastsq(full_gauss2,x0=[2,40,12942,50.0,5,5,12842,100.0,5,1,12942,1000.0,1,1,12942,1000.0,-0.001,0.1],args=(x,y,y_err),maxfev=100000000)
                
               # plt.plot(x,y)
                fit = full_gauss2(popt2,x,y,y_err)*(y_err)+y
               # plt.plot(x,fit,'r-',label='fit')
               # plt.show()
                
                (amp_Hb,amp_OIII5007,vel_OIII,vel_sigma_OIII,amp_Hb_br,amp_OIII5007_br,vel_OIII_br,vel_sigma_OIII_br,amp_Hb1,amp_Fe5018_1,vel_Hb1,vel_sigma_Hb1,amp_Hb2,amp_Fe5018_2,vel_Hb2,vel_sigma_Hb2,m,c)=popt2
                cor_popt2 = np.array([amp_OIII5007,amp_OIII5007_br,vel_OIII,vel_sigma_OIII,vel_OIII_br,vel_sigma_OIII_br])
                
                c = 3*(10**5)
                (wav_min,wav_max)=(4967*k,5037*k)
                wave = np.arange(wav_min,wav_max,0.02) 
                cumsum = np.cumsum(OIII_wo_cont(wave,*cor_popt2))
                norm_sum=cumsum/cumsum[-1]
    
                select = (norm_sum>0.1) & (norm_sum<0.9)
                w80_spec = wave[select][-1]-wave[select][0]
                   
                select =  (norm_sum>0.05) & (norm_sum<0.5)
                v5_spec = wave[select][0]-wave[select][-1]

                w80[i,j]=((w80_spec)/5006.8)*(c/(1+z))
                if w80[i,j]>3000:
                    w80[i,j]=0
                else:
                    w80[i,j] = w80[i,j]
                v5[i,j] = ((v5_spec)/5006.8)*(c/(1+z))
                
                #plt.legend
                #F_total = (2.507*(cor_popt2[0]*cor_popt2[4]) + 2.507*(cor_popt2[1]*cor_popt2[5]))*(10**-16)
                #flux_total[i,j] =  F_total
                #F_narrow = 2.507*(cor_popt2[0]*cor_popt2[4])*(10**-16)
                #F_broad = 2.507*(cor_popt2[1]*cor_popt2[5])*(10**-16)
                velshift_angstrom = (cor_popt2[2]-cor_popt2[3])
                #print cor_popt2[3]
                velshift_actual = (velshift_angstrom)/(cor_popt2[3])*(c/(1+z)) 
                vel_diff[i,j] = velshift_actual/100000 
                print('velocity shift is', vel_diff[i,j])
                print('w80',w80[i,j])
                print('v5',v5[i,j])
                                                              
        else:
             exit
# Out:
# velocity shift is 642.665
# w80 265.374
# v5 -145.899
# velocity shift is 629.022
# w80 273.416
# v5 -155.089
# velocity shift is 625.195
# w80 258.482
# v5 -151.643
# velocity shift is 490.945
# w80 261.928
# v5 -155.089
# velocity shift is 716.16
# w80 256.184
# v5 -150.494
# velocity shift is 590.063
# w80 263.077
# v5 -156.238
# velocity shift is 519.123
# w80 288.351
# v5 -163.131
# velocity shift is 523.483
# w80 295.243
# v5 -173.47
# velocity shift is 382.726
# w80 310.178
# v5 -184.958
# velocity shift is 493.247
# w80 315.922
# v5 -195.297
# velocity shift is 464.125
# w80 337.749
# v5 -201.041
# velocity shift is 169.136
# w80 298.69
# v5 -212.529
# velocity shift is 543.483
# w80 235.505
# v5 -141.303
# velocity shift is 600.449
# w80 238.952
# v5 -141.303
# velocity shift is 518.525
# w80 240.101
# v5 -145.899
# velocity shift is 640.197
# w80 240.101
# v5 -145.899
# velocity shift is 513.986
# w80 253.886
# v5 -153.94
# velocity shift is 461.19
# w80 269.97
# v5 -157.387
# velocity shift is 499.731
# w80 278.011
# v5 -165.428
# velocity shift is 406.341
# w80 298.69
# v5 -178.065
# velocity shift is 402.998
# w80 321.666
# v5 -191.851
# velocity shift is 464.234
# w80 333.154
# v5 -204.488
# velocity shift is 383.129
# w80 358.428
# v5 -222.869
# velocity shift is 558.928
# w80 205.636
# v5 -117.178
# velocity shift is 612.534
# w80 207.934
# v5 -125.22
# velocity shift is 686.68
# w80 219.422
# v5 -135.559
# velocity shift is 624.906
# w80 222.869
# v5 -140.154
# velocity shift is 583.488
# w80 233.208
# v5 -142.452
# velocity shift is 591.08
# w80 251.589
# v5 -153.94
# velocity shift is 482.369
# w80 268.821
# v5 -159.684
# velocity shift is 462.831
# w80 278.011
# v5 -167.726
# velocity shift is 455.647
# w80 295.243
# v5 -178.065
# velocity shift is 441.064
# w80 325.112
# v5 -198.744
# velocity shift is 396.718
# w80 333.154
# v5 -209.083
# velocity shift is 226.312
# w80 360.725
# v5 -230.91
# velocity shift is 374.885
# w80 352.684
# v5 -227.464
# velocity shift is 529.534
# w80 204.488
# v5 -125.22
# velocity shift is 581.281
# w80 204.488
# v5 -126.369
# velocity shift is 541.943
# w80 222.869
# v5 -137.857
# velocity shift is 526.817
# w80 232.059
# v5 -143.601
# velocity shift is 476.494
# w80 250.44
# v5 -150.494
# velocity shift is 474.729
# w80 267.672
# v5 -159.684
# velocity shift is 453.414
# w80 288.351
# v5 -168.875
# velocity shift is 451.498
# w80 298.69
# v5 -178.065
# velocity shift is 399.084
# w80 314.773
# v5 -194.148
# velocity shift is 429.784
# w80 337.749
# v5 -212.529
# velocity shift is -124.347
# w80 394.041
# v5 -315.922
# velocity shift is -123.935
# w80 425.059
# v5 -343.493
# velocity shift is -94.9824
# w80 423.91
# v5 -368.767
# velocity shift is 315.933
# w80 428.505
# v5 -361.874
# velocity shift is 537.853
# w80 204.488
# v5 -126.369
# velocity shift is 555.207
# w80 206.785
# v5 -126.369
# velocity shift is 487.34
# w80 232.059
# v5 -140.154
# velocity shift is 466.561
# w80 252.738
# v5 -150.494
# velocity shift is 415.763
# w80 278.011
# v5 -159.684
# velocity shift is 423.963
# w80 307.88
# v5 -174.619
# velocity shift is 436.197
# w80 329.708
# v5 -191.851
# velocity shift is 380.839
# w80 337.749
# v5 -209.083
# velocity shift is 327.879
# w80 350.386
# v5 -222.869
# velocity shift is 330.71
# w80 411.273
# v5 -330.856
# velocity shift is 127.115
# w80 420.463
# v5 -332.005
# velocity shift is 337.002
# w80 400.934
# v5 -258.482
# velocity shift is 298.764
# w80 454.928
# v5 -359.577
# velocity shift is 141.607
# w80 471.011
# v5 -334.303
# velocity shift is 578.924
# w80 199.892
# v5 -120.625
# velocity shift is 562.889
# w80 214.827
# v5 -126.369
# velocity shift is 499.844
# w80 246.994
# v5 -144.75
# velocity shift is 432.994
# w80 287.202
# v5 -158.535
# velocity shift is 411.469
# w80 327.41
# v5 -174.619
# velocity shift is 413.874
# w80 359.577
# v5 -201.041
# velocity shift is 318.837
# w80 383.702
# v5 -230.91
# velocity shift is 294.545
# w80 429.654
# v5 -323.964
# velocity shift is 313.434
# w80 437.696
# v5 -345.791
# velocity shift is 321.567
# w80 458.374
# v5 -366.47
# velocity shift is 319.684
# w80 467.565
# v5 -374.511
# velocity shift is 306.375
# w80 435.398
# v5 -284.904
# velocity shift is 123.415
# w80 489.392
# v5 -382.553
# velocity shift is 303.762
# w80 467.565
# v5 -336.601
# velocity shift is 523.174
# w80 210.232
# v5 -121.774
# velocity shift is 486.52
# w80 234.357
# v5 -130.964
# velocity shift is 458.538
# w80 282.607
# v5 -152.791
# velocity shift is 440.468
# w80 341.196
# v5 -179.214
# velocity shift is 431.495
# w80 377.958
# v5 -205.636
# velocity shift is 217.876
# w80 425.059
# v5 -257.333
# velocity shift is 119.864
# w80 468.713
# v5 -340.047
# velocity shift is 275.043
# w80 485.945
# v5 -372.214
# velocity shift is 297.616
# w80 495.136
# v5 -382.553
# velocity shift is 306.334
# w80 496.285
# v5 -387.148
# velocity shift is 310.246
# w80 513.517
# v5 -398.636
# velocity shift is 401.92
# w80 452.63
# v5 -282.607
# velocity shift is 281.937
# w80 537.642
# v5 -413.571
# velocity shift is 274.835
# w80 473.309
# v5 -333.154
# velocity shift is 504.459
# w80 244.696
# v5 -132.113
# velocity shift is 461.271
# w80 279.16
# v5 -145.899
# velocity shift is 453.847
# w80 336.601
# v5 -173.47
# velocity shift is -478.142
# w80 394.041
# v5 -218.273
# velocity shift is 575.397
# w80 421.612
# v5 -252.738
# velocity shift is 230.691
# w80 502.029
# v5 -361.874
# velocity shift is 255.567
# w80 499.731
# v5 -372.214
# velocity shift is 272.88
# w80 530.749
# v5 -404.38
# velocity shift is 285.869
# w80 543.386
# v5 -412.422
# velocity shift is 293.942
# w80 536.493
# v5 -404.38
# velocity shift is 287.574
# w80 536.493
# v5 -403.231
# velocity shift is 288.841
# w80 556.023
# v5 -411.273
# velocity shift is 288.936
# w80 538.791
# v5 -387.148
# velocity shift is 245.185
# w80 560.618
# v5 -399.785
# velocity shift is 253.37
# w80 572.106
# v5 -374.511
# velocity shift is 461.494
# w80 295.243
# v5 -149.345
# velocity shift is 471.58
# w80 319.368
# v5 -164.279
# velocity shift is 471.037
# w80 381.404
# v5 -203.339
# velocity shift is 480.35
# w80 405.529
# v5 -226.315
# velocity shift is 205.919
# w80 488.243
# v5 -306.732
# velocity shift is 239.689
# w80 520.41
# v5 -387.148
# velocity shift is 262.172
# w80 537.642
# v5 -400.934
# velocity shift is 273.609
# w80 558.32
# v5 -418.166
# velocity shift is 275.653
# w80 567.511
# v5 -422.761
# velocity shift is 285.228
# w80 562.916
# v5 -415.868
# velocity shift is 275.678
# w80 573.255
# v5 -425.059
# velocity shift is -274.795
# w80 553.725
# v5 -411.273
# velocity shift is 267.006
# w80 576.701
# v5 -406.678
# velocity shift is 192.246
# w80 508.922
# v5 -349.237
# velocity shift is -2.94338
# w80 0.0
# v5 -1867.96
# velocity shift is 430.996
# w80 357.279
# v5 -182.66
# velocity shift is 423.784
# w80 420.463
# v5 -230.91
# velocity shift is 1070.03
# w80 404.38
# v5 -243.547
# velocity shift is 2.17779e+07
# w80 472.16
# v5 -303.285
# velocity shift is 243.774
# w80 525.005
# v5 -388.297
# velocity shift is 260.305
# w80 542.237
# v5 -403.231
# velocity shift is 264.153
# w80 565.213
# v5 -419.315
# velocity shift is 264.389
# w80 582.445
# v5 -433.1
# velocity shift is 268.254
# w80 574.404
# v5 -427.356
# velocity shift is 286.249
# w80 559.469
# v5 -408.975
# velocity shift is 271.124
# w80 569.808
# v5 -421.612
# velocity shift is 258.194
# w80 595.082
# v5 -429.654
# velocity shift is 229.246
# w80 533.047
# v5 -390.594
# velocity shift is -594.695
# w80 361.874
# v5 -193.0
# velocity shift is 466.67
# w80 398.636
# v5 -214.827
# velocity shift is 505.437
# w80 425.059
# v5 -245.845
# velocity shift is 929.67
# w80 457.225
# v5 -282.607
# velocity shift is 208.71
# w80 554.874
# v5 -404.38
# velocity shift is 242.875
# w80 546.832
# v5 -400.934
# velocity shift is 260.669
# w80 557.172
# v5 -408.975
# velocity shift is 251.774
# w80 576.701
# v5 -422.761
# velocity shift is 271.022
# w80 575.552
# v5 -422.761
# velocity shift is 273.772
# w80 572.106
# v5 -428.505
# velocity shift is 292.644
# w80 573.255
# v5 -423.91
# velocity shift is 290.149
# w80 576.701
# v5 -421.612
# velocity shift is 225.306
# w80 566.362
# v5 -420.463
# velocity shift is 223.766
# w80 652.523
# v5 -489.392
# velocity shift is 1598.22
# w80 407.827
# v5 -255.035
# velocity shift is -360.166
# w80 507.773
# v5 -305.583
# velocity shift is -2.66076e+06
# w80 484.797
# v5 -311.327
# velocity shift is 230.149
# w80 553.725
# v5 -403.231
# velocity shift is 229.938
# w80 566.362
# v5 -422.761
# velocity shift is -240.705
# w80 578.999
# v5 -436.547
# velocity shift is 237.921
# w80 584.743
# v5 -436.547
# velocity shift is 259.222
# w80 582.445
# v5 -444.588
# velocity shift is 278.357
# w80 546.832
# v5 -403.231
# velocity shift is 270.984
# w80 572.106
# v5 -417.017
# velocity shift is 250.066
# w80 561.767
# v5 -406.678
# velocity shift is 357.623
# w80 536.493
# v5 -343.493
# velocity shift is -4.05839e+06
# w80 385.999
# v5 -246.994
# velocity shift is 373.639
# w80 507.773
# v5 -298.69
# velocity shift is 62.6293
# w80 588.189
# v5 -480.201
# velocity shift is 223.377
# w80 547.981
# v5 -397.487
# velocity shift is 235.345
# w80 567.511
# v5 -411.273
# velocity shift is 235.956
# w80 569.808
# v5 -420.463
# velocity shift is 234.437
# w80 562.916
# v5 -430.803
# velocity shift is 229.569
# w80 587.04
# v5 -454.928
# velocity shift is 262.848
# w80 541.088
# v5 -407.827
# velocity shift is 246.229
# w80 561.767
# v5 -410.124
# velocity shift is 229.003
# w80 582.445
# v5 -446.886
# velocity shift is 222.2
# w80 507.773
# v5 -349.237
# velocity shift is 115.968
# w80 569.808
# v5 -405.529
# velocity shift is 232.17
# w80 561.767
# v5 -397.487
# velocity shift is 252.346
# w80 543.386
# v5 -420.463
# velocity shift is 209.063
# w80 575.552
# v5 -452.63
# velocity shift is 287.601
# w80 505.475
# v5 -364.172
# velocity shift is 223.893
# w80 550.279
# v5 -402.083
# velocity shift is 130.927
# w80 584.743
# v5 -387.148

# %%
from matplotlib.colors import LogNorm
from matplotlib import cm
cmap=cm.gray
plt.imshow(w80,origin='lower',interpolation='nearest', cmap='gray', norm=LogNorm())
cbar = plt.colorbar()
plt.show()
#np.max(w80)
#if np.any(w80)1000:
#    w80 = 0
#else:
#    w80 = w80
#print (w80)
#len(w80>1000)
#print(np.where(w80>3000))
#if np.where(w80>1000):
#    w80=0
#else:
  #  w80 = w80
#print(w80)

# %%
fig = plt.figure()

cmap = cm.plasma
cmap.set_bad('white',1)

frame = plt.imshow(w80, origin='lower', cmap=cmap, norm=LogNorm(), interpolation='nearest')
cbar = plt.colorbar()
cbar.set_label(r"w80")

# %%
plt.imshow(vel_diff,origin='lower',interpolation='nearest',cmap='gray')
cbar = plt.colorbar()
cmap.set_bad('white',1)
plt.show()

# %%
fig = plt.figure()

cmap = cm.RdBu
cmap.set_bad('white',1)

frame = plt.imshow(vel_diff, origin='lower', cmap=cmap, norm=LogNorm(), interpolation='nearest')
cbar = plt.colorbar()
cbar.set_label(r"velocity shift")

# %%
w80_hdu = fits.PrimaryHDU(data=w80)
w80_hdu.writeto('w80_myfit.fits',clobber=True)

# %%
plt.imshow(v5,origin='lower',interpolation='nearest',cmap='gray', norm=LogNorm())
cbar = plt.colorbar()
plt.show()

# %%
plt.imshow(flux_total,origin='lower',interpolation='nearest',cmap='gray',norm=LogNorm())
cbar = plt.colorbar()
plt.show()

# %%
vel_diff_hdu = fits.PrimaryHDU(data=vel_diff)
vel_diff_hdu.writeto('vel_diff_myfit.fits',clobber=True)

# %%
flux_total_hdu = fits.PrimaryHDU(data=flux_total)
flux_total_hdu.writeto('flux_total_myfit.fits',clobber=True)

# %%
Flux= np.sum(flux_total)
Flux

# %%
D_L = 7.31*(10**26)
L_total = 31.5*((D_L)**2)*(Flux)/(2.507)
L_total

# %%
velocity_shift = velshift_actual/100000
velocity_shift

# %%
v5_final = v5_spec
v5_final

# %%
velocity_dispersion = w80_final/3.29
velocity_dispersion

# %%
from scipy import math
math.log10(L_total)

# %%
np.max(w80)
